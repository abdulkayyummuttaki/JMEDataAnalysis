# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\mutta\Documents\Project 6'
path
# Out:
# 'C:\\Users\\mutta\\Documents\\Project 6'

# %%
join = os.path.join(path, 
                    '02 Data', 
                    'Prepared Data',
                    '01 CSV',
                    '01. Sourcing Open Data',
                    'GLOBAL_DATAFLOW_2000-2023 stunting -2SD.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format


df = pd.read_csv(join, index_col = False, encoding= 'unicode_escape')
df.round(2)
df.head()
# Out:
#   Geographic area                                          Indicator    Sex  \
# 0     Afghanistan  Height-for-age <-2 SD (stunting), Modeled Esti...  Total
# 1     Afghanistan  Height-for-age <-2 SD (stunting), Modeled Esti...  Total
# 2     Afghanistan  Height-for-age <-2 SD (stunting), Modeled Esti...  Total
# 3     Afghanistan  Height-for-age <-2 SD (stunting), Modeled Esti...  Total
# 4     Afghanistan  Height-for-age <-2 SD (stunting), Modeled Esti...  Total
#
#    TIME_PERIOD  OBS_VALUE Unit multiplier Unit of measure Observation Status  \
# 0      2000.00      54.90           Units               %           Modelled
# 1      2001.00      55.00           Units               %           Modelled
# 2      2002.00      54.70           Units               %           Modelled
# 3      2003.00      54.30           Units               %           Modelled
# 4      2004.00      53.80           Units               %           Modelled
#
# ...

# %%
df.describe(include='all')
# Out:
#        Geographic area                                          Indicator  \
# count             3657                                               3657
# unique             159                                                  1
# top        Afghanistan  Height-for-age <-2 SD (stunting), Modeled Esti...
# freq                23                                               3657
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#           Sex  TIME_PERIOD  OBS_VALUE Unit multiplier Unit of measure  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Geographic area', 'Indicator', 'Sex', 'TIME_PERIOD', 'OBS_VALUE',
#        'Unit multiplier', 'Unit of measure', 'Observation Status',
#        'Observation confidentaility', 'LOWER_BOUND', 'UPPER_BOUND',
#        'WGTD_SAMPL_SIZE', 'OBS_FOOTNOTE', 'SERIES_FOOTNOTE', 'DATA_SOURCE',
#        'SOURCE_LINK', 'CUSTODIAN',
#        'Time period activity related to when the data are collected',
#        'REF_PERIOD', 'COVERAGE_TIME', 'Current age'],
#       dtype='object')

# %%
dimension = df.shape
print('rows:',dimension[0])
print('column:',dimension[1])
# Out:
# rows: 3658
# column: 21

# %%
print(df.dtypes)
# Out:
# Geographic area                                                 object
# Indicator                                                       object
# Sex                                                             object
# TIME_PERIOD                                                    float64
# OBS_VALUE                                                      float64
# Unit multiplier                                                 object
# Unit of measure                                                 object
# Observation Status                                              object
# Observation confidentaility                                     object
# LOWER_BOUND                                                    float64
# UPPER_BOUND                                                    float64
# WGTD_SAMPL_SIZE                                                float64
# OBS_FOOTNOTE                                                    object
# ...

# %%
df.isnull().sum()
# Out:
# Geographic area                                                   1
# Indicator                                                         1
# Sex                                                               1
# TIME_PERIOD                                                       1
# OBS_VALUE                                                         1
# Unit multiplier                                                   1
# Unit of measure                                                   1
# Observation Status                                                1
# Observation confidentaility                                       1
# LOWER_BOUND                                                       1
# UPPER_BOUND                                                       1
# WGTD_SAMPL_SIZE                                                3658
# OBS_FOOTNOTE                                                   3411
# SERIES_FOOTNOTE                                                   1
# ...

# %%
def validate_mixed_type_check(df):
    for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print ('Column', col, ' contains mixed types')
      else:
        print('Column', col ,'  contains same data types')
        
# 3. validate_mixed_type_check(df_orders)
validate_mixed_type_check(df)
# Out:
# Column Geographic area  contains mixed types
# Column Indicator  contains mixed types
# Column Sex  contains mixed types
# Column TIME_PERIOD   contains same data types
# Column OBS_VALUE   contains same data types
# Column Unit multiplier  contains mixed types
# Column Unit of measure  contains mixed types
# Column Observation Status  contains mixed types
# Column Observation confidentaility  contains mixed types
# Column LOWER_BOUND   contains same data types
# Column UPPER_BOUND   contains same data types
# Column WGTD_SAMPL_SIZE   contains same data types
# Column OBS_FOOTNOTE  contains mixed types
# Column SERIES_FOOTNOTE  contains mixed types
# Column DATA_SOURCE  contains mixed types
# Column SOURCE_LINK  contains mixed types
# Column CUSTODIAN  contains mixed types
# Column Time period activity related to when the data are collected  contains mixed types
# Column REF_PERIOD   contains same data types
# Column COVERAGE_TIME  contains mixed types
# ...

# %%
# Check for duplicate values
# df_dups = df[df.duplicated()]
# df_dups

# %%
# df.groupby(['Countries and areas']).count()

# %%
# df.groupby(['Year*']).count()

# %%
# df.groupby(['Countries and areas','Year*'])
