# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\mutta\Documents\Project 6'
path
# Out:
# 'C:\\Users\\mutta\\Documents\\Project 6'

# %%
join = os.path.join(path, 
                    '02 Data', 
                    'Prepared Data', 
                    '01 CSV',
                    '01. Sourcing Open Data',
                    'UNICEF_Global_Databases_Overweight.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format


df = pd.read_csv(join, index_col = False, encoding= 'unicode_escape')
df.round(2)
df.head()
# Out:
#    ISO Countries and areas UNICEF Regions UN Regions WHO Regions  \
# 0  AFG         Afghanistan             SA       Asia        EMRO
# 1  AFG         Afghanistan             SA       Asia        EMRO
# 2  AFG         Afghanistan             SA       Asia        EMRO
# 3  AFG         Afghanistan             SA       Asia        EMRO
# 4  ALB             Albania           EECA     Europe        EURO
#
#   World Bank Income Groups Survey Years  Year* Short Source  \
# 0               Low Income         1997   1997         MICS
# 1               Low Income         2004   2004          NNS
# 2               Low Income         2013   2013          NNS
# 3               Low Income         2018   2018        Other
# 4      Upper Middle Income         2005   2005         MICS
#
#                                    Full Source Title  ... 0-23 Point Estimate  \
# 0  Afghanistan 1997 multiple indicator baseline (...  ...                 NaN
# 1  Summary report of the national nutrition surve...  ...                 NaN
# 2         Afghanistan National Nutrition Survey 2013  ...                6.10
# 3                     Afghanistan Health Survey 2018  ...                5.30
# 4  Albania multiple indicator cluster survey 2005...  ...               22.20
#
#   0-23 Sample Size  24-35 Point Estimate  24-35 Sample Size  \
# 0              NaN                   NaN                NaN
# 1              NaN                  3.00             182.00
# 2       1801308.75                  5.00          836250.00
# 3          7593.22                  3.70            3955.94
# 4           374.95                 22.20             207.62
#
#    36-47 Point Estimate  36-47 Sample Size  48-59 Point Estimate  \
# 0                   NaN                NaN                   NaN
# 1                  5.60             227.00                  6.40
# 2                  5.10          821790.25                  4.30
# 3                  3.70            4209.26                  2.70
# 4                 25.20             226.69                 30.30
#
#    48-59 Sample Size  24-59 Point Estimate  24-59 Sample Size
# 0                NaN                   NaN                NaN
# 1             241.00                   NaN                NaN
# 2          787946.06                  4.80         2445986.25
# 3            3670.15                  3.40           11835.35
# 4             266.07                 26.30             700.38
#
# [5 rows x 38 columns]

# %%
df.describe()
# Out:
#         Year*  National Point Estimate  National Sample Size  \
# count  964.00                   964.00                912.00
# mean  2006.93                     6.09         2598596732.02
# std      9.10                     4.48        78184686740.25
# min   1983.00                     0.00                 86.91
# 25%   2000.00                     2.60               2892.43
# 50%   2008.00                     5.20               5762.78
# 75%   2014.00                     8.50              15740.85
# max   2022.00                    29.60      2361130000000.00
#
#        Male Point Estimate  Male Sample Size  Female Point Estimate  \
# count               847.00            823.00                 847.00
# mean                  6.45     1554162571.90                   5.69
# std                   4.74    44429664522.13                   4.37
# min                   0.00             42.77                   0.00
# 25%                   2.80           1453.26                   2.30
# 50%                   5.40           2816.36                   4.70
# 75%                   9.00           6934.23                   7.90
# max                  30.10  1274600000000.00                  29.10
#
#        Female Sample Size  Urban Point Estimate  Urban Sample Size  \
# count              823.00                658.00             646.00
# mean        1325416849.38                  6.89         5182581.58
# std        37873621981.42                  4.78        99376450.13
# min                 44.14                  0.00              48.84
# 25%               1407.66                  3.30             783.48
# 50%               2749.00                  5.80            1799.30
# 75%               6661.62                  9.30            4906.56
# max      1086520000000.00                 32.80      2458296832.00
#
#        Rural Point Estimate  ...  0-23 Point Estimate  0-23 Sample Size  \
# count                657.00  ...               750.00            739.00
# mean                   6.01  ...                 6.88     1302148455.90
# std                    4.60  ...                 4.99    35279278818.20
# min                    0.00  ...                 0.00             69.00
# 25%                    2.80  ...                 3.10           1271.50
# 50%                    4.90  ...                 5.90           2357.76
# 75%                    7.80  ...                 9.20           5456.77
# max                   32.80  ...                28.60   959054000000.00
#
#        24-35 Point Estimate  24-35 Sample Size  36-47 Point Estimate  \
# count                807.00             797.00                779.00
# mean                   5.60       706218138.12                  5.32
# std                    4.83     19873292305.51                  4.51
# min                    0.00              40.00                  0.00
# 25%                    1.90             585.79                  1.90
# 50%                    4.30            1129.03                  4.20
# 75%                    7.80            2714.69                  7.45
# max                   30.70    561048000000.00                 28.50
#
#        36-47 Sample Size  48-59 Point Estimate  48-59 Sample Size  \
# count             781.00                768.00             760.00
# mean        642292391.65                  4.70       450806014.20
# std       17881342606.94                  4.24     12363646464.48
# min                 0.48                  0.00               0.94
# 25%               598.51                  1.50             585.75
# 50%              1167.61                  3.50            1098.46
# 75%              2657.01                  6.70            2460.95
# max      499720000000.00                 30.30    340843000000.00
#
#        24-59 Point Estimate  24-59 Sample Size
# count                754.00             742.00
# mean                   5.13      1896344582.10
# std                    4.28     51454579414.39
# min                    0.00              40.00
# 25%                    1.90            1596.77
# 50%                    3.95            3305.41
# 75%                    7.30            7482.71
# max                   26.30   1401610000000.00
#
# [8 rows x 27 columns]

# %%
print(df.columns)
# Out:
# Index(['ISO', 'Countries and areas', 'UNICEF Regions', 'UN Regions',
#        'WHO Regions', 'World Bank Income Groups', 'Survey Years', 'Year*',
#        'Short Source', 'Full Source Title', 'Latest Estimate', 'Estimate Type',
#        'National Point Estimate', 'National Sample Size',
#        'Male Point Estimate', 'Male Sample Size', 'Female Point Estimate',
#        'Female Sample Size', 'Urban Point Estimate', 'Urban Sample Size',
#        'Rural Point Estimate', 'Rural Sample Size', '0-5 Point Estimate',
#        '0-5 Sample Size', '6-11 Point Estimate', '6-11 Sample Size',
#        '12-13 Point Estimate', '12-13 Sample Size', '0-23 Point Estimate',
#        '0-23 Sample Size', '24-35 Point Estimate', '24-35 Sample Size',
#        '36-47 Point Estimate', '36-47 Sample Size', '48-59 Point Estimate',
#        '48-59 Sample Size', '24-59 Point Estimate', '24-59 Sample Size'],
#       dtype='object')

# %%
dimension = df.shape
print('rows:',dimension[0])
print('column:',dimension[1])
# Out:
# rows: 964
# column: 38

# %%
print(df.dtypes)
# Out:
# ISO                          object
# Countries and areas          object
# UNICEF Regions               object
# UN Regions                   object
# WHO Regions                  object
# World Bank Income Groups     object
# Survey Years                 object
# Year*                         int64
# Short Source                 object
# Full Source Title            object
# Latest Estimate              object
# Estimate Type                object
# National Point Estimate     float64
# National Sample Size        float64
# Male Point Estimate         float64
# Male Sample Size            float64
# Female Point Estimate       float64
# Female Sample Size          float64
# Urban Point Estimate        float64
# Urban Sample Size           float64
# Rural Point Estimate        float64
# Rural Sample Size           float64
# 0-5 Point Estimate          float64
# 0-5 Sample Size             float64
# 6-11 Point Estimate         float64
# 6-11 Sample Size            float64
# 12-13 Point Estimate        float64
# 12-13 Sample Size           float64
# 0-23 Point Estimate         float64
# 0-23 Sample Size            float64
# 24-35 Point Estimate        float64
# 24-35 Sample Size           float64
# 36-47 Point Estimate        float64
# 36-47 Sample Size           float64
# 48-59 Point Estimate        float64
# 48-59 Sample Size           float64
# 24-59 Point Estimate        float64
# 24-59 Sample Size           float64
# dtype: object
