# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\mutta\Documents\Project 6'
path
# Out:
# 'C:\\Users\\mutta\\Documents\\Project 6'

# %%
join = os.path.join(path,
                    '02 Data',
                    'Prepared Data',
                    '01 CSV',
                    '01. Sourcing Open Data',
                    'UNICEF_Databases_Severe_Wasting.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format


df = pd.read_csv(join, index_col = False, encoding= 'unicode_escape')
df.round(2)
df.head()
# Out:
#    ISO Countries and areas UNICEF Regions UN Regions WHO Regions  \
# 0  AFG         Afghanistan             SA       Asia        EMRO
# 1  AFG         Afghanistan             SA       Asia        EMRO
# 2  AFG         Afghanistan             SA       Asia        EMRO
# 3  ALB             Albania           EECA     Europe        EURO
# 4  ALB             Albania           EECA     Europe        EURO
#
#   World Bank Income Groups Survey Years  Year* Short Source  \
# 0               Low Income         2004   2004          NNS
# 1               Low Income         2013   2013          NNS
# 2               Low Income         2018   2018        Other
# 3      Upper Middle Income         2005   2005         MICS
# 4      Upper Middle Income      2008-09   2009          DHS
#
#                                    Full Source Title  ...  \
# 0  Summary report of the national nutrition surve...  ...
# 1         Afghanistan National Nutrition Survey 2013  ...
# 2                     Afghanistan Health Survey 2018  ...
# 3  Albania multiple indicator cluster survey 2005...  ...
# 4  Albania demographic and health survey 2008-09....  ...
#
#   Female Point Estimate Urban Point Estimate  Rural Point Estimate  \
# 0                   NaN                  NaN                   NaN
# 1                  3.50                 1.90                  4.60
# 2                  1.40                 1.60                  1.50
# 3                  4.20                 2.20                  4.50
# 4                  4.30                 6.40                  5.60
#
#    0-5  months Point Estimate  6-11 months Point Estimate  \
# 0                         NaN                         NaN
# 1                        6.30                        5.50
# 2                        2.80                        2.80
# 3                        7.40                        1.00
# 4                       12.70                        5.50
#
#    12-13 months Point Estimate  24-35 months Point Estimate  \
# 0                          NaN                          NaN
# 1                         4.80                         3.50
# 2                         2.00                         1.40
# 3                         0.90                         5.20
# 4                         5.30                         5.20
#
#    36 - 47  Point Estimate  48-59 Point Estimate  24-59 Point Estimate
# 0                      NaN                   NaN                   NaN
# 1                     2.50                  2.80                  3.00
# 2                     0.70                  0.70                  0.90
# 3                     3.70                  3.80                  4.20
# 4                     5.90                  5.10                  5.40
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#         Year*  National Point Estimate  Male Point Estimate  \
# count  896.00                   896.00               745.00
# mean  2007.96                     1.90                 2.16
# std      8.70                     1.68                 1.83
# min   1983.00                     0.00                 0.00
# 25%   2001.00                     0.70                 0.80
# 50%   2009.00                     1.40                 1.70
# 75%   2015.00                     2.60                 3.00
# max   2022.00                    12.90                13.40
#
#        Female Point Estimate  Urban Point Estimate  Rural Point Estimate  \
# count                 745.00                587.00                586.00
# mean                    1.71                  1.85                  2.13
# std                     1.52                  1.62                  1.84
# min                     0.00                  0.00                  0.00
# 25%                     0.60                  0.70                  0.80
# 50%                     1.30                  1.30                  1.60
# 75%                     2.40                  2.50                  3.00
# max                    12.40                 11.30                 13.50
#
#        0-5  months Point Estimate  6-11 months Point Estimate  \
# count                      696.00                      706.00
# mean                         3.63                        3.05
# std                          2.94                        2.76
# min                          0.00                        0.00
# 25%                          1.40                        0.90
# 50%                          2.80                        2.30
# 75%                          5.30                        4.47
# max                         16.20                       14.00
#
#        12-13 months Point Estimate  24-35 months Point Estimate  \
# count                       706.00                       717.00
# mean                          2.33                         1.62
# std                           2.15                         1.61
# min                           0.00                         0.00
# 25%                           0.70                         0.50
# 50%                           1.80                         1.20
# 75%                           3.30                         2.20
# max                          13.50                        13.90
#
#        36 - 47  Point Estimate  48-59 Point Estimate  24-59 Point Estimate
# count                   717.00                717.00                661.00
# mean                      1.25                  1.20                  1.32
# std                       1.37                  1.29                  1.26
# min                       0.00                  0.00                  0.00
# 25%                       0.40                  0.40                  0.50
# 50%                       0.80                  0.80                  0.90
# 75%                       1.70                  1.60                  1.80
# max                      12.70                 12.50                  9.60

# %%
print(df.columns)
# Out:
# Index(['ISO', 'Countries and areas', 'UNICEF Regions', 'UN Regions',
#        'WHO Regions', 'World Bank Income Groups', 'Survey Years', 'Year*',
#        'Short Source', 'Full Source Title', 'Latest Estimate', 'Estimate Type',
#        'National Point Estimate', 'Male Point Estimate',
#        'Female Point Estimate', 'Urban Point Estimate', 'Rural Point Estimate',
#        '0-5  months Point Estimate', '6-11 months Point Estimate',
#        '12-13 months Point Estimate', '24-35 months Point Estimate',
#        '36 - 47  Point Estimate', '48-59 Point Estimate',
#        '24-59 Point Estimate'],
#       dtype='object')

# %%
dimension = df.shape
print('rows:',dimension[0])
print('column:',dimension[1])
# Out:
# rows: 896
# column: 24

# %%
print(df.dtypes)
# Out:
# ISO                             object
# Countries and areas             object
# UNICEF Regions                  object
# UN Regions                      object
# WHO Regions                     object
# World Bank Income Groups        object
# Survey Years                    object
# Year*                            int64
# Short Source                    object
# Full Source Title               object
# Latest Estimate                 object
# Estimate Type                   object
# National Point Estimate        float64
# Male Point Estimate            float64
# Female Point Estimate          float64
# Urban Point Estimate           float64
# Rural Point Estimate           float64
# 0-5  months Point Estimate     float64
# 6-11 months Point Estimate     float64
# 12-13 months Point Estimate    float64
# 24-35 months Point Estimate    float64
# 36 - 47  Point Estimate        float64
# 48-59 Point Estimate           float64
# 24-59 Point Estimate           float64
# dtype: object
