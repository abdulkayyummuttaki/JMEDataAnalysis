# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\mutta\Documents\Project 6'
path
# Out:
# 'C:\\Users\\mutta\\Documents\\Project 6'

# %%
join = os.path.join(path, 
                    '02 Data', 
                    'Prepared Data', 
                    '01 CSV',
                    '01. Sourcing Open Data',
                    'UNICEF_Global_Databases_Mortality.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format


df = pd.read_csv(join, index_col = False, encoding= 'unicode_escape')

df.round(2)
df.head()
# Out:
# C:\Users\mutta\AppData\Local\Temp\ipykernel_2260\3122783834.py:4: DtypeWarning: Columns (4,5,10,11,14,16,17,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(join, index_col = False, encoding= 'unicode_escape')
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  CME_ARR_10T19: Annual Rate of Reduction in Mor...  _T: Total
# 1  CME_ARR_SBR: Annual rate of reduction in still...  _T: Total
# ...

# %%
df.describe(include='all')
# Out:
#                                                  DATAFLOW  \
# count                                             1967354
# unique                                                  1
# top     UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...
# freq                                              1967354
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        REF_AREA:Geographic area           INDICATOR:Indicator    SEX:Sex  \
# count                   1967354                       1967354    1967354
# unique                      304                           403          3
# ...

# %%
print(df.columns)
# Out:
# Index(['DATAFLOW', 'REF_AREA:Geographic area', 'INDICATOR:Indicator',
#        'SEX:Sex', 'TIME_PERIOD:Time period', 'OBS_VALUE:Observation Value',
#        'UNIT_MULTIPLIER:Unit multiplier', 'UNIT_MEASURE:Unit of measure',
#        'OBS_STATUS:Observation Status', 'OBS_CONF:Observation confidentaility',
#        'LOWER_BOUND:Lower Bound', 'UPPER_BOUND:Upper Bound',
#        'WGTD_SAMPL_SIZE:Weighted Sample Size',
#        'OBS_FOOTNOTE:Observation footnote', 'SERIES_FOOTNOTE:Series footnote',
#        'DATA_SOURCE:Data Source',
#        'SOURCE_LINK:Citation of or link to the data source',
#        'CUSTODIAN:Custodian',
#        'TIME_PERIOD_METHOD:Time period activity related to when the data are collected',
#        'REF_PERIOD:Reference Period',
#        'COVERAGE_TIME:The period of time for which data are provided',
#        'AGE:Current age'],
#       dtype='object')

# %%
dimension = df.shape
print('rows:',dimension[0])
print('column:',dimension[1])
# Out:
# rows: 1967354
# column: 22

# %%
print(df.dtypes)
# Out:
# DATAFLOW                                                                           object
# REF_AREA:Geographic area                                                           object
# INDICATOR:Indicator                                                                object
# SEX:Sex                                                                            object
# TIME_PERIOD:Time period                                                            object
# OBS_VALUE:Observation Value                                                        object
# UNIT_MULTIPLIER:Unit multiplier                                                    object
# UNIT_MEASURE:Unit of measure                                                       object
# OBS_STATUS:Observation Status                                                      object
# OBS_CONF:Observation confidentaility                                               object
# ...
